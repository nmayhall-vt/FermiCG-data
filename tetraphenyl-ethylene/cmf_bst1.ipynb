# %%
pwd()
# Out:
# "/Users/nmayhall/code/FermiCG-data/tetraphenyl-ethylene"

# %%
using Pkg; Pkg.activate("../../FermiCG/")
# Out:
#   Activating project at `~/code/FermiCG`

# %%
using FermiCG, NPZ
readdir()
# Out:
# 7-element Vector{String}:
#  ".ipynb_checkpoints"
#  "Untitled.ipynb"
#  "Untitled1.ipynb"
#  "tetraphenyl-ethylene_scf_integrals_h0.npz.npy"
#  "tetraphenyl-ethylene_scf_integrals_h1.npz.npy"
#  "tetraphenyl-ethylene_scf_integrals_h2.npz.npy"
#  "tetraphenyl-ethylene_scf_integrals_scf.ipynb"

# %%
h0 = npzread("tetraphenyl-ethylene_scf_integrals_h0.npz.npy")
h1 = npzread("tetraphenyl-ethylene_scf_integrals_h1.npz.npy")
h2 = npzread("tetraphenyl-ethylene_scf_integrals_h2.npz.npy");
ints = InCoreInts(h0, h1, h2)
print(size(h0), size(h1), size(h2))
# Out:
# ()(26, 26)(26, 26, 26, 26)

# %%
# Define clusters

clusters_in = [
    (1:6),   # Benzene 1
    (7:12),  # Benzene 2
    (13:18), # Benzene 3
    (19:24), # Benzene 4
    (25:26)  # ethylene
]
clusters = [Cluster(i,collect(clusters_in[i])) for i = 1:length(clusters_in)]

init_fspace = [
    (3,3),
    (3,3),
    (3,3),
    (3,3),
    (1,1)
];
print(clusters)
print(init_fspace)
# Out:
# Cluster[Cluster(1, [1, 2, 3, 4, 5, 6]), Cluster(2, [7, 8, 9, 10, 11, 12]), Cluster(3, [13, 14, 15, 16, 17, 18]), Cluster(4, [19, 20, 21, 22, 23, 24]), Cluster(5, [25, 26])][(3, 3), (3, 3), (3, 3), (3, 3), (1, 1)]

# %%
rdm1 = zeros(size(ints.h1))

e_cmf, U, da1, db1 = FermiCG.cmf_oo(ints, clusters, init_fspace, rdm1, rdm1, verbose=0, gconv=1e-6, method="cg",sequential=true)
# Out:
#  ooCMF Iter:    1 Total= -996.455149805120 Active= -56.434499391698 G=     4.10e-01
#  ooCMF Iter:    2 Total= -996.506021982933 Active= -56.485371569511 G=     1.23e-01
#  ooCMF Iter:    3 Total= -996.509527941702 Active= -56.488877528280 G=     3.26e-02
#  ooCMF Iter:    4 Total= -996.509796385318 Active= -56.489145971895 G=     1.14e-02
#  ooCMF Iter:    5 Total= -996.509845067303 Active= -56.489194653881 G=     9.47e-03
#  ooCMF Iter:    6 Total= -996.509889841844 Active= -56.489239428421 G=     1.42e-02
#  ooCMF Iter:    7 Total= -996.509925609487 Active= -56.489275196065 G=     3.69e-03
#  ooCMF Iter:    8 Total= -996.509928915462 Active= -56.489278502040 G=     1.37e-03
#  ooCMF Iter:    9 Total= -996.509929496637 Active= -56.489279083215 G=     8.77e-04
#  ooCMF Iter:   10 Total= -996.509930077131 Active= -56.489279663709 G=     7.74e-04
#  ooCMF Iter:   11 Total= -996.509930420986 Active= -56.489280007564 G=     6.41e-04
#  ooCMF Iter:   12 Total= -996.509930512158 Active= -56.489280098736 G=     2.25e-04
#  ooCMF Iter:   13 Total= -996.509930522544 Active= -56.489280109122 G=     6.67e-05
#  ooCMF Iter:   14 Total= -996.509930523949 Active= -56.489280110527 G=     3.45e-05
#  ooCMF Iter:   15 Total= -996.509930524839 Active= -56.489280111416 G=     3.55e-05
#  ooCMF Iter:   16 Total= -996.509930525588 Active= -56.489280112165 G=     4.01e-05
#  ooCMF Iter:   17 Total= -996.509930525915 Active= -56.489280112493 G=     1.10e-05
#  ooCMF Iter:   18 Total= -996.509930525945 Active= -56.489280112523 G=     4.31e-06
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     -9.965099e+02
#
#  * Found with
#     Algorithm:     Conjugate Gradient
#
#  * Convergence measures
#     |x - x'|               = 9.42e-07 ≰ 0.0e+00
#     |x - x'|/|x'|          = 1.07e-05 ≰ 0.0e+00
#     |f(x) - f(x')|         = 7.73e-12 ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 7.76e-15 ≰ 0.0e+00
#     |g(x)|                 = 7.58e-07 ≤ 1.0e-06
#
#  * Work counters
#     Seconds run:   65  (vs limit Inf)
#     Iterations:    18
#     f(x) calls:    38
#     ∇f(x) calls:   20
#  ooCMF Iter:   19 Total= -996.509930525953 Active= -56.489280112531 G=     3.20e-06
# *ooCMF -996.50993053
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = npyinitialize() at numpy.jl:67
# └ @ PyCall /Users/nmayhall/.julia/packages/PyCall/L0fLP/src/numpy.jl:67
# (-996.5099305259529, [0.9977547571356454 -0.0003955093758401743 … 0.0030941045394172867 -0.05813366481962749; -0.0003994116499125076 0.9955343077321928 … 0.08913388329051541 -0.004339931604790121; … ; -0.0038219555234603247 -0.08605720975555212 … 0.9828759172541472 0.0018854572156978213; 0.06138223588080552 0.005512872790828114 … 0.0018854568175240998 0.9828759224592218], [0.5023443685036915 0.30976377408901346 … -1.1740826832237731e-17 -6.7373071232167885e-18; 0.3097637740890133 0.49822560931493365 … -4.0149807243800134e-17 3.753190153479234e-17; … ; -6.660806097852673e-18 -2.8861740387284615e-17 … 0.4999999975413946 0.4580815439880761; 1.253580341317993e-17 2.3477254695090783e-17 … 0.45808154398807605 0.500000002458606], [0.5023443685036914 0.30976377408901323 … -8.717876862590494e-18 -1.87139404149074e-17; 0.30976377408901307 0.49822560931493554 … -5.782418082466934e-17 3.011771900185415e-17; … ; 3.74753475800817e-18 -2.3657569959354193e-17 … 0.49999999754139435 0.4580815439880761; 1.575705687288763e-17 2.4701358355932166e-17 … 0.45808154398807605 0.5000000024586062])

# %%
# rotate integrals to new basis
ints = FermiCG.orbital_rotation(ints,U)
# Out:
# InCoreInts(-940.0206504134221, [-3.861417494314357 -0.13108845765170576 … -0.01630434668657372 -0.03332957372249018; -0.13108845765170893 -4.348615650395219 … 0.023929497387423115 -0.03706933664674345; … ; -0.016304346686572962 0.02392949738742245 … -4.4935405572105145 -0.14180567901244007; -0.033329573722489736 -0.03706933664674732 … -0.14180567901244706 -4.493540522745169], [0.5917712291181507 -0.0006332858065492972 … 0.0006343245828694383 -0.0214258948139293; -0.0006332858065492609 0.31423064627605285 … 0.016879107695710955 -0.002158030511617294; … ; 0.0006343245828694454 0.016879107695710962 … 0.1416678772993833 -0.0010898276965827646; -0.021425894813929293 -0.0021580305116172776 … -0
# %%
Da = da1
Db = db1 
max_roots = 20

#
# form Cluster data
cluster_bases = FermiCG.compute_cluster_eigenbasis(ints, clusters, verbose=0,
                                                   max_roots=max_roots,
                                                   init_fspace=init_fspace,
                                                   rdm1a=Da, rdm1b=Db)

clustered_ham = FermiCG.extract_ClusteredTerms(ints, clusters)
cluster_ops = FermiCG.compute_cluster_ops(cluster_bases, ints);
FermiCG.add_cmf_operators!(cluster_ops, cluster_bases, ints, Da, Db);

check = 0.0
for ci_ops in cluster_ops
    for (opstr, ops) in ci_ops
        for (ftrans, op) in ops
            check += sum(abs.(op))
        end
    end
end
# Out:
#  Remove duplicates
#  Number of terms reduced from  2525 to  1105

# %%
# Create BST state

v = FermiCG.BSTstate(clusters, FockConfig(init_fspace), cluster_bases)


xspace  = FermiCG.build_compressed_1st_order_state(v, cluster_ops, clustered_ham, nbody=3, thresh=1e-3)
xspace = FermiCG.compress(xspace, thresh=1e-3)
display(size(xspace))

FermiCG.nonorth_add!(v, xspace)
v = FermiCG.BSTstate(v,R=6)
FermiCG.randomize!(v)
FermiCG.orthonormalize!(v)

e_ci, v = FermiCG.tucker_ci_solve(v, cluster_ops, clustered_ham)
# Out:
#  Number of tasks:                                         661
#  Compute tasks:                                     54.827184 seconds (1.31 M allocations: 139.821 MiB, 31.94% compilation time)
#  Add results together:                               1.294205 seconds (182.47 k allocations: 14.145 MiB, 54.53% compilation time)
# (421, 1)
#  |== BST CI ========================================================
#  Solve CI with # variables:                               421
#  Cache Hamiltonian:                                 24.203975 seconds (5.60 M allocations: 697.065 MiB, 56.10% gc time)
#  Iter:   1 SS: 6    E:  -55.79918078   -55.78993163   -55.78397007   -55.77443897   -55.75752167   -55.74737510   R: 1.8e-01  1.9e-01  2.1e-01  2.0e-01  1.8e-01  1.9e-01   LinDep: 1.0e+00*
#  Iter:   2 SS: 12   E:  -56.07425812   -55.98621225   -55.97694628   -55.97605292   -55.92948577   -55.91760417   R: 3.3e-01  1.8e-01  1.6e-01  1.8e-01  1.7e-01  1.8e-01   LinDep: 1.0e+00*
#  Iter:   3 SS: 18   E:  -56.38115594   -56.08768197   -56.08356719   -56.06546834   -56.03640054   -56.02543270   R: 2.4e-01  1.3e-01  1.2e-01  1.1e-01  1.3e-01  1.3e-01   LinDep: 1.0e+00*
#  Iter:   4 SS: 24   E:  -56.48051843   -56.13213807   -56.12393705   -56.10279195   -56.09406946   -56.07783766   R: 1.0e-01  7.4e-02  8.0e-02  8.1e-02  9.0e-02  8.8e-02   LinDep: 1.0e+00*
#  Iter:   5 SS: 30   E:  -56.49623944   -56.15415360   -56.14784414   -56.13520845   -56.12879931   -56.11152722   R: 3.0e-02  5.7e-02  5.8e-02  6.9e-02  6.8e-02  7.3e-02   LinDep: 1.0e+00*
#  Iter:   6 SS: 36   E:  -56.49769795   -56.16967296   -56.16146484   -56.15436925   -56.14839326   -56.13807160   R: 8.9e-03  4.3e-02  4.2e-02  4.7e-02  4.7e-02  6.1e-02   LinDep: 1.0e+00*
#      0.025           4         57           2:20    1:1    1:1    1:1    2:4
#      0.014           4         361          2:20    1:1   2:20    1:1    1:1
#      0.025           4         57            1:1   2:20    1:1    1:1    2:4
#      0.025           4         57            1:1    1:1    1:1   2:20    2:4
#      0.013           1         361           1:1   2:20   2:20    1:1    1:1
#      0.013           1         361          2:20    1:1    1:1   2:20    1:1
#      0.014           4         361           1:1   2:20    1:1   2:20    1:1
#      0.025           4         57            1:1    1:1   2:20    1:1    2:4
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 3,3 )( 3,3 )( 4,2 )( 0,2 )
#      0.014           1         20            1:1    1:1    1:1   1:20    1:1
#  ---------                               ----------
#  0.014                                   ( 4,2 )( 3,3 )( 3,3 )( 3,3 )( 0,2 )
#      0.014           1         20           1:20    1:1    1:1    1:1    1:1
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 2,3 )( 3,3 )( 2,1 )
#      0.022           4         40            1:1    1:1   1:20    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 4,3 )( 3,3 )( 3,3 )( 3,3 )( 0,1 )
#      0.022           4         40           1:20    1:1    1:1    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,3 )( 3,4 )( 1,0 )
#      0.022           4         40            1:1    1:1    1:1   1:20    1:2
#  ---------                               ----------
#  0.023                                   ( 3,2 )( 3,3 )( 3,3 )( 3,3 )( 1,2 )
#      0.022           4         40           1:20    1:1    1:1    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,2 )( 3,3 )( 3,3 )( 1,2 )
#      0.022           4         40            1:1   1:20    1:1    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 2,3 )( 3,3 )( 3,3 )( 2,1 )
#      0.022           4         40            1:1   1:20    1:1    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,2 )( 3,3 )( 1,2 )
#      0.022           4         40            1:1    1:1   1:20    1:1    1:2
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 4,2 )( 3,3 )( 3,3 )( 0,2 )
#      0.014           1         20            1:1   1:20    1:1    1:1    1:1
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 3,3 )( 3,3 )( 2,4 )( 2,0 )
#      0.014           1         20            1:1    1:1    1:1   1:20    1:1
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,4 )( 3,3 )( 1,0 )
#      0.022           4         40            1:1    1:1   1:20    1:1    1:2
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 3,3 )( 4,2 )( 3,3 )( 0,2 )
#      0.014           1         20            1:1    1:1   1:20    1:1    1:1
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 3,3 )( 2,4 )( 3,3 )( 2,0 )
#      0.014           1         20            1:1    1:1   1:20    1:1    1:1
#  ---------                               ----------
#  0.023                                   ( 3,4 )( 3,3 )( 3,3 )( 3,3 )( 1,0 )
#      0.022           4         40           1:20    1:1    1:1    1:1    1:2
#  ---------                               ----------
#  0.014                                   ( 3,3 )( 2,4 )( 3,3 )( 3,3 )( 2,0 )
#      0.014           1         20            1:1   1:20    1:1    1:1    1:1
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,3 )( 2,3 )( 2,1 )
#      0.022           4         40            1:1    1:1    1:1   1:20    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,3 )( 3,2 )( 1,2 )
#      0.022           4         40            1:1    1:1    1:1   1:20    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,4 )( 3,3 )( 3,3 )( 1,0 )
#      0.022           4         40            1:1   1:20    1:1    1:1    1:2
#  ---------                               ----------
#  0.014                                   ( 2,4 )( 3,3 )( 3,3 )( 3,3 )( 2,0 )
#      0.014           1         20           1:20    1:1    1:1    1:1    1:1
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 4,3 )( 3,3 )( 0,1 )
#      0.022           4         40            1:1    1:1   1:20    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 3,3 )( 3,3 )( 4,3 )( 0,1 )
#      0.022           4         40            1:1    1:1    1:1   1:20    1:2
#  ---------                               ----------
#  0.023                                   ( 3,3 )( 4,3 )( 3,3 )( 3,3 )( 0,1 )
#      0.022           4         40            1:1   1:20    1:1    1:1    1:2
#  ---------                               ----------
#  0.023                                   ( 2,3 )( 3,3 )( 3,3 )( 3,3 )( 2,1 )
#      0.022           4         40           1:20    1:1    1:1    1:1    1:2
#  ---------                               ----------
#  --------------------------------------------------

# %%
using Printf
for ei in 1:length(e_ci)
    @printf(" %5i %12.8f %12.8f eV\n", ei, e_ci[ei]+ints.h0, (e_ci[ei]-e_ci[1])*27.21165)
end
# Out:
#      1 -996.51640098   0.00000000 eV
#      2 -996.21535342   8.19200091 eV
#      3 -996.21376101   8.23533300 eV
#      4 -996.21069221   8.31884002 eV
#      5 -996.20568091   8.45520563 eV
#      6 -996.19955212   8.62198018 eV

# %%
 e_var, v_var = FermiCG.block_sparse_tucker(v, cluster_ops, clustered_ham,
                                        max_iter    = 20,
                                        max_iter_pt = 200,
                                        nbody       = 4,
                                        H0          = "Hcmf",
                                        thresh_var  = 1e-1,
                                        thresh_foi  = 1e-3,
                                        thresh_pt   = 1e-3,
                                        ci_conv     = 1e-5,
                                        do_pt       = true,                          
                                        resolve_ss  = false,
                                        tol_tucker  = 1e-4)
# Out:
#  max_iter       : 20
#  max_iter_pt    : 200
#  nbody          : 4
#  H0             : Hcmf
#  thresh_var     : 0.1
#  thresh_foi     : 0.001
#  thresh_pt      : 0.001
#  ci_conv        : 1.0e-5
#  ci_max_iter    : 50
#  ci_max_ss_vecs : 12
#  resolve_ss     : false
#  do_pt          : true
#  tol_tucker     : 0.0001
#
#
#
#  ===================================================================
#      BST Iteration:    1 epsilon:   0.10000000
#  ===================================================================
#  Ref state compressed from:                               285 → 53         (thresh =  1.0e-01)
#  Compute zeroth-order energy:                        2.030396 seconds (3.22 M allocations: 231.880 MiB)
#  Compute <S^2>:                                      0.109545 seconds (297.41 k allocations: 20.049 MiB)
#   Root       Energy           S2
#      1 -56.49069915   0.00023657
#      2 -56.19290826   0.07468772
#      3 -56.19203954   2.00000001
#      4 -56.18783785   0.08658230
#      5 -56.18240483   0.09033100
#      6 -56.17686831   0.11370102
#
#  Compute FOIS. Reference space dim:                        53
#  Number of tasks:                                         661
#  Compute tasks:
# TaskFailedException
#
#     nested task error: MethodError: no method matching contract_dense_H_with_state(::FermiCG.ClusteredTerm4B, ::Array{Float64, 8}, ::Int64, ::FermiCG.Tucker{Float64, 5, 1}, ::FermiCG.Tucker{Float64, 5, 6})
#     Closest candidates are:
#       contract_dense_H_with_state(::FermiCG.ClusteredTerm4B, ::Any, ::Any, ::FermiCG.Tucker{T, N, R}, ::FermiCG.Tucker{T, N, R}) where {T, N, R} at ~/code/FermiCG/src/tucker_contract_dense_H_with_state.jl:247
#       contract_dense_H_with_state(::FermiCG.ClusteredTerm1B, ::Any, ::Any, ::FermiCG.Tucker{T, N, R}, ::FermiCG.Tucker{T, N, R}) where {T, N, R} at ~/code/FermiCG/src/tucker_contract_dense_H_with_state.jl:4
#       contract_dense_H_with_state(::FermiCG.ClusteredTerm2B, ::Any, ::Any, ::FermiCG.Tucker{T, N, R}, ::FermiCG.Tucker{T, N, R}) where {T, N, R} at ~/code/FermiCG/src/tucker_contract_dense_H_with_state.jl:82
#       ...
#     Stacktrace:
#      [1] form_sigma_block_expand(term::FermiCG.ClusteredTerm4B, cluster_ops::Vector{FermiCG.ClusterOps}, fock_bra::FockConfig{5}, bra::TuckerConfig{5}, fock_ket::FockConfig{5}, ket::TuckerConfig{5}, coeffs_ket::FermiCG.Tucker{Float64, 5, 6}; precontract::Bool, max_number::Nothing, prescreen::Float64)
#        @ FermiCG ~/code/FermiCG/src/tucker_form_sigma_block_expand.jl:708
#      [2] macro expansion
#        @ ~/code/FermiCG/src/tucker_outer.jl:791 [inlined]
#      [3] (::FermiCG.var"#538#threadsfor_fun#220"{Float64, Nothing, Int64, FermiCG.BSTstate{Float64, 5, 6}, Vector{FermiCG.ClusterOps}, FermiCG.ClusteredOperator, Vector{Vector{Vector{Float64}}}, ReentrantLock, OrderedCollections.OrderedDict{FockConfig{5}, OrderedCollections.OrderedDict{TuckerConfig{5}, Vector{FermiCG.Tucker{Float64, 5, 6}}}}, Vector{FermiCG.TransferConfig{5}}})(onethread::Bool)
#        @ FermiCG ./threadingconstructs.jl:85
#      [4] (::FermiCG.var"#538#threadsfor_fun#220"{Float64, Nothing, Int64, FermiCG.BSTstate{Float64, 5, 6}, Vector{FermiCG.ClusterOps}, FermiCG.ClusteredOperator, Vector{Vector{Vector{Float64}}}, ReentrantLock, OrderedCollections.OrderedDict{FockConfig{5}, OrderedCollections.OrderedDict{TuckerConfig{5}, Vector{FermiCG.Tucker{Float64, 5, 6}}}}, Vector{FermiCG.TransferConfig{5}}})()
#        @ FermiCG ./threadingconstructs.jl:52
#
# Stacktrace:
#   [1] wait
#     @ ./task.jl:334 [inlined]
#   [2] threading_run(func::Function)
#     @ Base.Threads ./threadingconstructs.jl:38
#   [3] macro expansion
#     @ ./threadingconstructs.jl:97 [inlined]
#   [4] macro expansion
#     @ ./timing.jl:220 [inlined]
#   [5] build_compressed_1st_order_state(ket_cts::FermiCG.BSTstate{Float64, 5, 6}, cluster_ops::Vector{FermiCG.ClusterOps}, clustered_ham::FermiCG.ClusteredOperator; thresh::Float64, max_number::Nothing, nbody::Int64)
#     @ FermiCG ~/code/FermiCG/src/tucker_outer.jl:697
#   [6] macro expansion
#     @ ~/.julia/packages/TimerOutputs/5tW2E/src/TimerOutput.jl:236 [inlined]
#   [7] macro expansion
#     @ ./timing.jl:299 [inlined]
#   [8] block_sparse_tucker(input_vec::FermiCG.BSTstate{Float64, 5, 6}, cluster_ops::Vector{FermiCG.ClusterOps}, clustered_ham::FermiCG.ClusteredOperator; max_iter::Int64, max_iter_pt::Int64, nbody::Int64, H0::String, thresh_var::Float64, thresh_foi::Float64, thresh_pt::Float64, ci_conv::Float64, ci_max_iter::Int64, ci_max_ss_vecs::Int64, resolve_ss::Bool, do_pt::Bool, tol_tucker::Float64)
#     @ FermiCG ~/code/FermiCG/src/bst.jl:141
#   [9] top-level scope
#     @ In[41]:1
#  [10] eval
#     @ ./boot.jl:373 [inlined]
#  [11] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196
